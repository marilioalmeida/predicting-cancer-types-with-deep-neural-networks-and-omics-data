# %%
import code_share
from code_share import TRAINING_SET_PATH, TRAINING_LABEL_PATH, OUT_FILE_NAME, TESTING_SET_PATH, TESTING_LABEL_PATH, FILENAME_LIST_PATH, INPUT_SAVE_MODEL_PATH, NUM_EPCHS 
from code_share import MCC, save_train_history, evaluate_model

import os
import warnings
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from datetime import datetime as DT
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, AveragePooling2D, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard, Callback
from tensorflow.keras.layers import BatchNormalization as B_nor
from tensorflow.keras import layers, models, regularizers
import tensorflow.keras.backend as K
from tensorflow import keras
from sklearn.metrics import f1_score, precision_score, recall_score, matthews_corrcoef
import pandas as pd

# Set environment variables
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

warnings.filterwarnings('ignore')
matplotlib.use("Agg")
 
# Function to build the CNN model
def build_cnn_model(input_shape):
    model = Sequential()

    # 1st Convolutional Layer
    model.add(Conv2D(filters=96, input_shape=input_shape, kernel_size=(11, 11), strides=(4, 4), padding='valid', activation='relu'))
    model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='valid'))

    # 2nd Convolutional Layer
    model.add(Conv2D(filters=256, kernel_size=(5, 5), strides=(1, 1), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='valid'))
  
     # Flatten the output
    model.add(Flatten())

    # 1st Fully Connected Layer
    model.add(Dense(4096, activation='relu'))

    # 2nd Fully Connected Layer
    model.add(Dense(4096, activation='relu'))

    # Output Layer
    model.add(Dense(12, activation='softmax'))  # Assuming binary classification; change output layer size for different number of classes
    return model 





# Load and preprocess training data
x_sample = np.load(TRAINING_SET_PATH)
x_sample = x_sample.reshape((x_sample.shape[0], 100, 100, 1))

y_label = np.load(TRAINING_LABEL_PATH)
y_label = to_categorical(y_label) 

# Build CNN model
model = build_cnn_model(x_sample[0].shape)
model.summary()

# Compile model
adam = Adam(learning_rate=1e-4)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy', MCC])

# Define callbacks
best_model_path = OUT_FILE_NAME + "_best_weights.keras"
estop = EarlyStopping(monitor="val_MCC", patience=60, verbose=0, mode="max")
checkpoint = ModelCheckpoint(best_model_path, monitor="val_MCC", verbose=0, save_best_only=True, mode="max")
tb_callback = TensorBoard(log_dir=OUT_FILE_NAME + '_logs', histogram_freq=0, write_graph=True, write_images=False, embeddings_freq=0, embeddings_metadata=None, update_freq='epoch')

# Train model
train_history = model.fit(x_sample, y_label, validation_split=0.25, epochs=NUM_EPCHS, batch_size=24, verbose=1, callbacks=[estop, checkpoint, tb_callback])

# Save training log
with open(OUT_FILE_NAME + "_tranning_message", 'w') as out:
    for step, (i, mcc) in enumerate(zip(train_history.history['accuracy'], train_history.history['MCC']), 1):
        out.write(f'Epoch:\t{step}/{NUM_EPCHS}\tLoss:\t{train_history.history["loss"][step-1]:.6f}\tAcc:\t{i:.6f}\tMCC:\t{mcc:.6f}\tVal_Loss:\t{train_history.history["val_loss"][step-1]:.6f}\tVal_Acc:\t{train_history.history["val_accuracy"][step-1]:.6f}\tVal_MCC:\t{train_history.history["val_MCC"][step-1]:.6f}\n')

# Save final model
final_model = OUT_FILE_NAME + ".weights.h5"
model.save_weights(final_model)

# Plot training history
save_train_history(train_history, "accuracy", "val_accuracy", OUT_FILE_NAME + "-acc")
save_train_history(train_history, "loss", "val_loss", OUT_FILE_NAME + "-loss")

# Load testing data and labels
test_sample = np.load(TESTING_SET_PATH)
test_sample = test_sample.reshape((test_sample.shape[0], 100, 100, 1))

test_label = np.load(TESTING_LABEL_PATH)
test_label_compare = test_label
test_label = to_categorical(test_label)

test_sample_title = np.load(FILENAME_LIST_PATH)
 
model = build_cnn_model(test_sample[0].shape)

evaluate_model(model, "AlexNetLayer2", test_sample, test_sample_title, test_label, test_label_compare)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 23, 23, 96)        11712
#
#  max_pooling2d (MaxPooling2D  (None, 11, 11, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 256)       614656
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense (Dense)               (None, 4096)              26218496
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 12)                49164
#
# =================================================================
# Total params: 43,675,340
# Trainable params: 43,675,340
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 39/39 [==============================] - 3s 40ms/step - loss: 2.4219 - accuracy: 0.2628 - MCC: 0.0070 - val_loss: 1.9781 - val_accuracy: 0.2573 - val_MCC: 0.0151
# Epoch 2/100
# 39/39 [==============================] - 1s 35ms/step - loss: 1.4016 - accuracy: 0.5744 - MCC: 0.3923 - val_loss: 0.9845 - val_accuracy: 0.6840 - val_MCC: 0.6448
# Epoch 3/100
# 39/39 [==============================] - 1s 34ms/step - loss: 0.6403 - accuracy: 0.8024 - MCC: 0.7589 - val_loss: 0.6912 - val_accuracy: 0.7915 - val_MCC: 0.7262
# Epoch 4/100
# 39/39 [==============================] - 1s 33ms/step - loss: 0.3935 - accuracy: 0.8632 - MCC: 0.8424 - val_loss: 0.4656 - val_accuracy: 0.8534 - val_MCC: 0.8489
# Epoch 5/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.2858 - accuracy: 0.9131 - MCC: 0.8993 - val_loss: 0.4891 - val_accuracy: 0.8567 - val_MCC: 0.8332
# Epoch 6/100
# 39/39 [==============================] - 1s 33ms/step - loss: 0.2407 - accuracy: 0.9175 - MCC: 0.9114 - val_loss: 0.4439 - val_accuracy: 0.8664 - val_MCC: 0.8527
# Epoch 7/100
# 39/39 [==============================] - 1s 32ms/step - loss: 0.2462 - accuracy: 0.9218 - MCC: 0.9137 - val_loss: 0.3996 - val_accuracy: 0.8795 - val_MCC: 0.8586
# Epoch 8/100
# 39/39 [==============================] - 1s 34ms/step - loss: 0.1572 - accuracy: 0.9598 - MCC: 0.9540 - val_loss: 0.2624 - val_accuracy: 0.9186 - val_MCC: 0.9101
# Epoch 9/100
# 39/39 [==============================] - 1s 34ms/step - loss: 0.1319 - accuracy: 0.9533 - MCC: 0.9485 - val_loss: 0.2903 - val_accuracy: 0.9153 - val_MCC: 0.9109
# Epoch 10/100
# 39/39 [==============================] - 1s 36ms/step - loss: 0.1285 - accuracy: 0.9577 - MCC: 0.9525 - val_loss: 0.2900 - val_accuracy: 0.9153 - val_MCC: 0.9122
# Epoch 11/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.1192 - accuracy: 0.9631 - MCC: 0.9608 - val_loss: 0.3645 - val_accuracy: 0.9023 - val_MCC: 0.8979
# Epoch 12/100
# 39/39 [==============================] - 1s 33ms/step - loss: 0.1097 - accuracy: 0.9696 - MCC: 0.9671 - val_loss: 0.2799 - val_accuracy: 0.9316 - val_MCC: 0.9247
# Epoch 13/100
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0698 - accuracy: 0.9761 - MCC: 0.9718 - val_loss: 0.2376 - val_accuracy: 0.9349 - val_MCC: 0.9298
# Epoch 14/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0774 - accuracy: 0.9783 - MCC: 0.9772 - val_loss: 0.2308 - val_accuracy: 0.9283 - val_MCC: 0.9200
# Epoch 15/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0780 - accuracy: 0.9772 - MCC: 0.9760 - val_loss: 0.4796 - val_accuracy: 0.8795 - val_MCC: 0.8707
# Epoch 16/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0728 - accuracy: 0.9696 - MCC: 0.9690 - val_loss: 0.2839 - val_accuracy: 0.9251 - val_MCC: 0.9236
# Epoch 17/100
# 39/39 [==============================] - 1s 33ms/step - loss: 0.0574 - accuracy: 0.9826 - MCC: 0.9802 - val_loss: 0.2307 - val_accuracy: 0.9414 - val_MCC: 0.9350
# Epoch 18/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.0399 - accuracy: 0.9881 - MCC: 0.9877 - val_loss: 0.3303 - val_accuracy: 0.9121 - val_MCC: 0.9095
# Epoch 19/100
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0377 - accuracy: 0.9815 - MCC: 0.9819 - val_loss: 0.2477 - val_accuracy: 0.9479 - val_MCC: 0.9473
# Epoch 20/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0783 - accuracy: 0.9707 - MCC: 0.9660 - val_loss: 0.2305 - val_accuracy: 0.9283 - val_MCC: 0.9201
# Epoch 21/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0873 - accuracy: 0.9739 - MCC: 0.9707 - val_loss: 0.2180 - val_accuracy: 0.9446 - val_MCC: 0.9384
# Epoch 22/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0366 - accuracy: 0.9891 - MCC: 0.9864 - val_loss: 0.2677 - val_accuracy: 0.9381 - val_MCC: 0.9386
# Epoch 23/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0873 - accuracy: 0.9707 - MCC: 0.9707 - val_loss: 0.4682 - val_accuracy: 0.9088 - val_MCC: 0.9067
# Epoch 24/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0491 - accuracy: 0.9815 - MCC: 0.9807 - val_loss: 0.2941 - val_accuracy: 0.9381 - val_MCC: 0.9369
# Epoch 25/100
# 39/39 [==============================] - 1s 32ms/step - loss: 0.0198 - accuracy: 0.9957 - MCC: 0.9953 - val_loss: 0.2186 - val_accuracy: 0.9511 - val_MCC: 0.9509
# Epoch 26/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.0137 - accuracy: 0.9946 - MCC: 0.9942 - val_loss: 0.2369 - val_accuracy: 0.9446 - val_MCC: 0.9404
# Epoch 27/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.0102 - accuracy: 0.9989 - MCC: 0.9988 - val_loss: 0.2532 - val_accuracy: 0.9446 - val_MCC: 0.9439
# Epoch 28/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0044 - accuracy: 1.0000 - MCC: 1.0000 - val_loss: 0.2405 - val_accuracy: 0.9446 - val_MCC: 0.9406
# Epoch 29/100
# 39/39 [==============================] - 1s 37ms/step - loss: 0.0040 - accuracy: 1.0000 - MCC: 1.0000 - val_loss: 0.2273 - val_accuracy: 0.9544 - val_MCC: 0.9510
# Epoch 30/100
# 39/39 [==============================] - 1s 35ms/step - loss: 0.0031 - accuracy: 1.0000 - MCC: 1.0000 - val_loss: 0.2240 - val_accuracy: 0.9609 - val_MCC: 0.9578
# Epoch 31/100
# 39/39 [==============================] - 1s 34ms/step - loss: 0.0030 - accuracy: 1.0000 - MCC: 1.0000 - val_loss: 0.2448 - val_accuracy: 0.9577 - val_MCC: 0.9580
# Epoch 32/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0031 - accuracy: 1.0000 - MCC: 1.0000 - val_loss: 0.2770 - val_accuracy: 0.9446 - val_MCC: 0.9439
# Epoch 33/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0050 - accuracy: 0.9989 - MCC: 0.9988 - val_loss: 0.2753 - val_accuracy: 0.9446 - val_MCC: 0.9406
# Epoch 34/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.0377 - accuracy: 0.9881 - MCC: 0.9846 - val_loss: 0.3292 - val_accuracy: 0.9186 - val_MCC: 0.9157
# Epoch 35/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0609 - accuracy: 0.9859 - MCC: 0.9842 - val_loss: 0.2453 - val_accuracy: 0.9511 - val_MCC: 0.9508
# Epoch 36/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.0217 - accuracy: 0.9946 - MCC: 0.9948 - val_loss: 0.6671 - val_accuracy: 0.8502 - val_MCC: 0.8344
# Epoch 37/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.1234 - accuracy: 0.9544 - MCC: 0.9532 - val_loss: 0.2821 - val_accuracy: 0.9381 - val_MCC: 0.9334
# Epoch 38/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.0294 - accuracy: 0.9913 - MCC: 0.9913 - val_loss: 0.2454 - val_accuracy: 0.9446 - val_MCC: 0.9439
# Epoch 39/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0270 - accuracy: 0.9913 - MCC: 0.9906 - val_loss: 0.3355 - val_accuracy: 0.9186 - val_MCC: 0.9142
# Epoch 40/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0127 - accuracy: 0.9978 - MCC: 0.9971 - val_loss: 0.3479 - val_accuracy: 0.9479 - val_MCC: 0.9473
# Epoch 41/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0150 - accuracy: 0.9967 - MCC: 0.9965 - val_loss: 0.2635 - val_accuracy: 0.9381 - val_MCC: 0.9352
# Epoch 42/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0182 - accuracy: 0.9935 - MCC: 0.9930 - val_loss: 0.4019 - val_accuracy: 0.9414 - val_MCC: 0.9387
# Epoch 43/100
# 39/39 [==============================] - 1s 14ms/step - loss: 0.0158 - accuracy: 0.9967 - MCC: 0.9965 - val_loss: 0.2860 - val_accuracy: 0.9381 - val_MCC: 0.9368
# Epoch 44/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0025 - accuracy: 1.0000 - MCC: 1.0000 - val_loss: 0.2387 - val_accuracy: 0.9511 - val_MCC: 0.9492
# Epoch 45/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0017 - accuracy: 1.0000 - MCC: 1.0000 - val_loss: 0.2593 - val_accuracy: 0.9414 - val_MCC: 0.9387
# Epoch 46/100
# 39/39 [==============================] - 1s 13ms/step - loss: 0.0010 - accuracy: 1.0000 - MCC: 1.0000 - val_loss: 0.